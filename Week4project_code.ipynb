# %% [markdown]
# ### Methodology
# ---

# %%
# importing libraries
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json
from pandas.io.json import json_normalize
import folium
import geopy.geocoders

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

print('Libraries are imported.')
# Out:
# Libraries are imported.

# %% [markdown]
# #### 3.1 Create a dataset of postal codes in Toronto

# %%
# same dataset with the one in week 3
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
source = requests.get(url).text
soup = BeautifulSoup(source, 'lxml')
table = soup.find('table')

Postalcode = []
Borough = []
Neighbourhood = []

for tr_cell in table.find_all('tr'):
    for td_cell in tr_cell.find_all('td'):
        if td_cell.span.text != 'Not assigned':
            code = td_cell.b.text
            locat = td_cell.span.text
            if '(' in locat:
                bor = locat[:locat.find('(')]
                hood = locat[locat.find('(')+1:locat.find(')')].replace('/',',')
            else:
                bor = locat[locat.find('/')+2:]
                hood = locat[:locat.find('/')-1]
            Postalcode.append(code)
            Borough.append(bor)
            Neighbourhood.append(hood)
            
err1 = 'MississaugaCanada Post Gateway Processing Centre'
Borough[Borough.index(err1)] = 'Mississauga Canada Post Gateway Processing Centre'
err2 = 'East TorontoBusiness reply mail Processing Centre969 Eastern'
Borough[Borough.index(err2)] = 'East Toronto Business reply mail Processing Centre969 Eastern'

coordinate = pd.read_csv('Geospatial_Coordinates.csv')
coordinate.set_index('Postal Code', inplace = True)
latitude = []
longitude = []
for i in range(coordinate.shape[0]):
    latitude.append(coordinate.loc[Postalcode[i],'Latitude'])
    longitude.append(coordinate.loc[Postalcode[i],'Longitude'])
coordinate_dict = {'Postalcode': Postalcode, 
                   'Borough': Borough, 
                   'Neighbourhood': Neighbourhood, 
                   'Latitude': latitude, 
                   'Longitude': longitude}
df_toronto = pd.DataFrame.from_dict(coordinate_dict)
df_toronto.head()
# Out:
#   Postalcode                        Borough  \
# 0        M3A                     North York
# 1        M4A                     North York
# 2        M5A               Downtown Toronto
# 3        M6A                     North York
# 4        M7A  Ontario Provincial Government
#
#                        Neighbourhood   Latitude  Longitude
# 0                          Parkwoods  43.753259 -79.329656
# 1                   Victoria Village  43.725882 -79.315572
# 2         Regent Park , Harbourfront  43.654260 -79.360636
# 3  Lawrence Manor , Lawrence Heights  43.718518 -79.464763
# 4                       Queen's Park  43.662301 -79.389494

# %% [markdown]
# #### 3.2 Create a map of postal codes' region in Toronto

# %%
# for the city Toronto, latitude and longtitude are manually extracted via google search
toronto_latitude = 43.6932
toronto_longitude = -79.3832
map_toronto = folium.Map(location = [toronto_latitude, toronto_longitude], zoom_start = 10.7)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_toronto['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 3.3 Focus on the Etobicoke in Toronto

# %%
# selecting only neighborhoods regarding to Etobicoke
etobicoke_data = df_toronto[df_toronto['Borough'] == 'Etobicoke']
etobicoke_data = etobicoke_data.reset_index(drop=True)
etobicoke_data
# Out:
#    Postalcode    Borough                                      Neighbourhood  \
# 0         M9A  Etobicoke                                   Islington Avenue
# 1         M9B  Etobicoke  West Deane Park , Princess Gardens , Martin Gr...
# 2         M9C  Etobicoke  Eringate , Bloordale Gardens , Old Burnhamthor...
# 3         M9P  Etobicoke                                          Westmount
# 4         M9R  Etobicoke  Kingsview Village , St. Phillips , Martin Grov...
# 5         M8V  Etobicoke     New Toronto , Mimico South , Humber Bay Shores
# 6         M9V  Etobicoke  South Steeles , Silverstone , Humbergate , Jam...
# 7         M8W  Etobicoke                            Alderwood , Long Branch
# 8         M8X  Etobicoke    The Kingsway , Montgomery Road , Old Mill North
# 9         M8Y  Etobicoke  Old Mill South , King's Mill Park , Sunnylea ,...
# 10        M8Z  Etobicoke  Mimico NW , The Queensway West , South of Bloo...
#
#      Latitude  Longitude
# 0   43.667856 -79.532242
# 1   43.650943 -79.554724
# 2   43.643515 -79.577201
# 3   43.696319 -79.532242
# 4   43.688905 -79.554724
# 5   43.605647 -79.501321
# 6   43.739416 -79.588437
# 7   43.602414 -79.543484
# 8   43.653654 -79.506944
# 9   43.636258 -79.498509
# 10  43.628841 -79.520999

# %% [markdown]
# #### 3.4 Create a map of Etobicoke and its neighbourhoods

# %%
address_etbc = 'Etobicoke, Toronto'
latitude_etbc = 43.66
longitude_etbc = -79.54
print('The geograpical coordinate of Etobicoke are: {}, {}.'.format(latitude_etbc, longitude_etbc))
# Out:
# The geograpical coordinate of Etobicoke are: 43.66, -79.54.

# %%
map_Etobicoke = folium.Map(location=[latitude_etbc, longitude_etbc], zoom_start=11)

# add markers to map
for lat, lng, label in zip(etobicoke_data['Latitude'], 
                           etobicoke_data['Longitude'], 
                           etobicoke_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius = 10,
        popup = label,
        color ='blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7).add_to(map_Etobicoke)  
    
map_Etobicoke
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 3.5 Crawl Foursquare database for venues in the neighborhoods of Etobicoke

# %%
CLIENT_ID = 'ADWDOUGGD32EEVAXCTWCNCCA52GVGFU003G1QXRIGOPUACYV'
CLIENT_SECRET = 'CQYLABIZUIXLUGURGP0G2HYTRGAEDL5Y422A5ULVZYTQVFFK'
VERSION = '20180605'

# %%
def foursquare_crawler (postal_code_list, neighborhood_list, lat_list, lng_list, LIMIT = 500, radius = 1000):
    result_ds = []
    counter = 0
    for postal_code, neighborhood, lat, lng in zip(postal_code_list, neighborhood_list, lat_list, lng_list):
         
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng,
            radius,
            LIMIT)
            
        results = requests.get(url).json()["response"]['groups'][0]['items']
        tmp_dict = {}
        tmp_dict['Postal Code'] = postal_code
        tmp_dict['Neighborhood(s)'] = neighborhood 
        tmp_dict['Latitude'] = lat
        tmp_dict['Longitude'] = lng
        tmp_dict['Crawling_result'] = results
        result_ds.append(tmp_dict)
        counter += 1
        print('{}. Postal Code {} and Neighborhoods {}, data collected.'.format(counter, postal_code, neighborhood))
    return result_ds;

# %%
print('Crawling different neighborhoods of Etobicoke:')
Etobicoke_foursquare_dataset = foursquare_crawler(list(etobicoke_data['Postalcode']),
                                                   list(etobicoke_data['Neighbourhood']),
                                                   list(etobicoke_data['Latitude']),
                                                   list(etobicoke_data['Longitude']))
# Out:
# Crawling different neighborhoods of Etobicoke:
# 1. Postal Code M9A and Neighborhoods Islington Avenue, data collected.
# 2. Postal Code M9B and Neighborhoods West Deane Park , Princess Gardens , Martin Grove , Islington , Cloverdale, data collected.
# 3. Postal Code M9C and Neighborhoods Eringate , Bloordale Gardens , Old Burnhamthorpe , Markland Wood, data collected.
# 4. Postal Code M9P and Neighborhoods Westmount, data collected.
# 5. Postal Code M9R and Neighborhoods Kingsview Village , St. Phillips , Martin Grove Gardens , Richview Gardens, data collected.
# 6. Postal Code M8V and Neighborhoods New Toronto , Mimico South , Humber Bay Shores, data collected.
# 7. Postal Code M9V and Neighborhoods South Steeles , Silverstone , Humbergate , Jamestown , Mount Olive , Beaumond Heights , Thistletown , Albion Gardens, data collected.
# 8. Postal Code M8W and Neighborhoods Alderwood , Long Branch, data collected.
# 9. Postal Code M8X and Neighborhoods The Kingsway , Montgomery Road , Old Mill North, data collected.
# 10. Postal Code M8Y and Neighborhoods Old Mill South , King's Mill Park , Sunnylea , Humber Bay , Mimico NE , The Queensway East , Royal York South East , Kingsway Park South East, data collected.
# 11. Postal Code M8Z and Neighborhoods Mimico NW , The Queensway West , South of Bloor , Kingsway Park South West , Royal York South West, data collected.

# %% [markdown]
# #### 3.6 Clean the data of venues from Foursqure database

# %%
# This function will extract venues for every neighborhood in the dataset(list).
def get_venue_dataset(foursquare_dataset):
    result_df = pd.DataFrame(columns = ['Postal Code', 'Neighborhood', 
                                           'Neighborhood Latitude', 'Neighborhood Longitude',
                                          'Venue', 'Venue Summary', 'Venue Category', 'Distance'])
    
    for neigh_dict in foursquare_dataset:
        postal_code = neigh_dict['Postal Code']
        neigh = neigh_dict['Neighborhood(s)']
        lat = neigh_dict['Latitude']
        lng = neigh_dict['Longitude']
        print('Number of Venues in Coordination "{}" Posal Code and "{}" Negihborhood(s) is {} \n'.format(postal_code, neigh, len(neigh_dict['Crawling_result'])))
        
        for venue_dict in neigh_dict['Crawling_result']:
            summary = venue_dict['reasons']['items'][0]['summary']
            name = venue_dict['venue']['name']
            dist = venue_dict['venue']['location']['distance']
            cat =  venue_dict['venue']['categories'][0]['name']
                        
            result_df = result_df.append({'Postal Code': postal_code, 'Neighborhood': neigh, 
                              'Neighborhood Latitude': lat, 'Neighborhood Longitude':lng,
                              'Venue': name, 'Venue Summary': summary, 
                              'Venue Category': cat, 'Distance': dist}, ignore_index = True)

    return(result_df)

# %%
etobicoke_venues = get_venue_dataset(Etobicoke_foursquare_dataset)
# Out:
# Number of Venues in Coordination "M9A" Posal Code and "Islington Avenue" Negihborhood(s) is 12
#
# Number of Venues in Coordination "M9B" Posal Code and "West Deane Park , Princess Gardens , Martin Grove , Islington , Cloverdale" Negihborhood(s) is 15
#
# Number of Venues in Coordination "M9C" Posal Code and "Eringate , Bloordale Gardens , Old Burnhamthorpe , Markland Wood" Negihborhood(s) is 19
#
# Number of Venues in Coordination "M9P" Posal Code and "Westmount" Negihborhood(s) is 15
#
# Number of Venues in Coordination "M9R" Posal Code and "Kingsview Village , St. Phillips , Martin Grove Gardens , Richview Gardens" Negihborhood(s) is 17
#
# Number of Venues in Coordination "M8V" Posal Code and "New Toronto , Mimico South , Humber Bay Shores" Negihborhood(s) is 19
#
# Number of Venues in Coordination "M9V" Posal Code and "South Steeles , Silverstone , Humbergate , Jamestown , Mount Olive , Beaumond Heights , Thistletown , Albion Gardens" Negihborhood(s) is 18
#
# Number of Venues in Coordination "M8W" Posal Code and "Alderwood , Long Branch" Negihborhood(s) is 26
#
# Number of Venues in Coordination "M8X" Posal Code and "The Kingsway , Montgomery Road , Old Mill North" Negihborhood(s) is 47
#
# Number of Venues in Coordination "M8Y" Posal Code and "Old Mill South , King's Mill Park , Sunnylea , Humber Bay , Mimico NE , The Queensway East , Royal York South East , Kingsway Park South East" Negihborhood(s) is 7
#
# Number of Venues in Coordination "M8Z" Posal Code and "Mimico NW , The Queensway West , South of Bloor , Kingsway Park South West , Royal York South West" Negihborhood(s) is 60

# %% [markdown]
# #### 3.7 Show venues for each neighborhood in Etobicoke

# %%
etobicoke_venues.head()
# Out:
#   Postal Code      Neighborhood  Neighborhood Latitude  \
# 0         M9A  Islington Avenue              43.667856
# 1         M9A  Islington Avenue              43.667856
# 2         M9A  Islington Avenue              43.667856
# 3         M9A  Islington Avenue              43.667856
# 4         M9A  Islington Avenue              43.667856
#
#    Neighborhood Longitude                             Venue  \
# 0              -79.532242           Java Joe's Village Cafe
# 1              -79.532242  St Georges Golf and Country Club
# 2              -79.532242                   TD Canada Trust
# 3              -79.532242                Shoppers Drug Mart
# 4              -79.532242                        COBS Bread
#
#           Venue Summary Venue Category Distance
# 0  This spot is popular           Café      600
# 1  This spot is popular    Golf Course      827
# 2  This spot is popular           Bank      592
# 3  This spot is popular       Pharmacy      534
# 4  This spot is popular         Bakery     1000

# %%
# save a cleaned version of dataframe
etobicoke_venues.to_csv('etobicoke_venues.csv')
# load data from csv file
etobicoke_venues = pd.read_csv('etobicoke_venues.csv')

# %%
# summarize the data information
neigh_list = list(etobicoke_venues['Neighborhood'].unique())
neigh_venue_summary = etobicoke_venues.groupby('Neighborhood').count()
neigh_venue_summary.drop(columns = ['Unnamed: 0'], inplace = True)
neigh_venue_summary
# Out:
#                                                     Postal Code  \
# Neighborhood
# Alderwood , Long Branch                                      26
# Eringate , Bloordale Gardens , Old Burnhamthorp...           19
# Islington Avenue                                             12
# Kingsview Village , St. Phillips , Martin Grove...           17
# Mimico NW , The Queensway West , South of Bloor...           60
# New Toronto , Mimico South , Humber Bay Shores               19
# Old Mill South , King's Mill Park , Sunnylea , ...            7
# South Steeles , Silverstone , Humbergate , Jame...           18
# The Kingsway , Montgomery Road , Old Mill North              47
# West Deane Park , Princess Gardens , Martin Gro...           15
# Westmount                                                    15
#
#                                                     Neighborhood Latitude  \
# Neighborhood
# Alderwood , Long Branch                                                26
# Eringate , Bloordale Gardens , Old Burnhamthorp...                     19
# Islington Avenue                                                       12
# Kingsview Village , St. Phillips , Martin Grove...                     17
# Mimico NW , The Queensway West , South of Bloor...                     60
# New Toronto , Mimico South , Humber Bay Shores                         19
# Old Mill South , King's Mill Park , Sunnylea , ...                      7
# South Steeles , Silverstone , Humbergate , Jame...                     18
# The Kingsway , Montgomery Road , Old Mill North                        47
# West Deane Park , Princess Gardens , Martin Gro...                     15
# Westmount                                                              15
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Alderwood , Long Branch                                                 26
# Eringate , Bloordale Gardens , Old Burnhamthorp...                      19
# Islington Avenue                                                        12
# Kingsview Village , St. Phillips , Martin Grove...                      17
# Mimico NW , The Queensway West , South of Bloor...                      60
# New Toronto , Mimico South , Humber Bay Shores                          19
# Old Mill South , King's Mill Park , Sunnylea , ...                       7
# South Steeles , Silverstone , Humbergate , Jame...                      18
# The Kingsway , Montgomery Road , Old Mill North                         47
# West Deane Park , Princess Gardens , Martin Gro...                      15
# Westmount                                                               15
#
#                                                     Venue  Venue Summary  \
# Neighborhood
# Alderwood , Long Branch                                26             26
# Eringate , Bloordale Gardens , Old Burnhamthorp...     19             19
# Islington Avenue                                       12             12
# Kingsview Village , St. Phillips , Martin Grove...     17             17
# Mimico NW , The Queensway West , South of Bloor...     60             60
# New Toronto , Mimico South , Humber Bay Shores         19             19
# Old Mill South , King's Mill Park , Sunnylea , ...      7              7
# South Steeles , Silverstone , Humbergate , Jame...     18             18
# The Kingsway , Montgomery Road , Old Mill North        47             47
# West Deane Park , Princess Gardens , Martin Gro...     15             15
# Westmount                                              15             15
#
#                                                     Venue Category  Distance
# Neighborhood
# Alderwood , Long Branch                                         26        26
# Eringate , Bloordale Gardens , Old Burnhamthorp...              19        19
# Islington Avenue                                                12        12
# Kingsview Village , St. Phillips , Martin Grove...              17        17
# Mimico NW , The Queensway West , South of Bloor...              60        60
# New Toronto , Mimico South , Humber Bay Shores                  19        19
# Old Mill South , King's Mill Park , Sunnylea , ...               7         7
# South Steeles , Silverstone , Humbergate , Jame...              18        18
# The Kingsway , Montgomery Road , Old Mill North                 47        47
# West Deane Park , Princess Gardens , Martin Gro...              15        15
# Westmount                                                       15        15

# %%
print('There are {} uniques categories.\n'.format(len(etobicoke_venues['Venue Category'].unique())))
print('Here is the list of different categories:')
list(etobicoke_venues['Venue Category'].unique())
# Out:
# There are 91 uniques categories.
#
# Here is the list of different categories:
# ['Café',
#  'Golf Course',
#  'Bank',
#  'Pharmacy',
#  'Bakery',
#  'Grocery Store',
#  'Shopping Mall',
#  'Playground',
#  'Park',
#  'Skating Rink',
#  'Convenience Store',
#  'Fish & Chips Shop',
#  'Restaurant',
#  'Pizza Place',
#  'Gym',
#  'Theater',
#  'Mexican Restaurant',
#  'Hotel',
#  'Clothing Store',
#  'Liquor Store',
#  'Coffee Shop',
#  'Beer Store',
#  'Farmers Market',
#  'Cosmetics Shop',
#  'College Rec Center',
#  'Gas Station',
#  'Shopping Plaza',
#  'Pet Store',
#  'Transportation Service',
#  'Chinese Restaurant',
#  'Sandwich Place',
#  'Supermarket',
#  'Intersection',
#  'Discount Store',
#  'Ice Cream Shop',
#  'Flea Market',
#  'Breakfast Spot',
#  'Bus Line',
#  'Mobile Phone Shop',
#  'American Restaurant',
#  'Supplement Shop',
#  'Electronics Store',
#  'Dessert Shop',
#  'Italian Restaurant',
#  'Indian Restaurant',
#  'Pub',
#  'Fried Chicken Joint',
#  'Fast Food Restaurant',
#  'Hardware Store',
#  'Gym Pool',
#  'Caribbean Restaurant',
#  'Construction & Landscaping',
#  'Moroccan Restaurant',
#  'Pool',
#  'Donut Shop',
#  'Trail',
#  'Garden Center',
#  'Sushi Restaurant',
#  'French Restaurant',
#  'Tapas Restaurant',
#  'Seafood Restaurant',
#  'Pool Hall',
#  'Thai Restaurant',
#  'Burger Joint',
#  'Gastropub',
#  'Toy / Game Store',
#  'Indie Movie Theater',
#  'Greek Restaurant',
#  'Gourmet Shop',
#  'Bar',
#  'River',
#  'Cupcake Shop',
#  'Lighting Store',
#  'Eastern European Restaurant',
#  'Gym / Fitness Center',
#  'Wings Joint',
#  'Burrito Place',
#  'Yoga Studio',
#  'Movie Theater',
#  'Middle Eastern Restaurant',
#  'BBQ Joint',
#  'Comfort Food Restaurant',
#  'Asian Restaurant',
#  'Social Club',
#  'Tanning Salon',
#  'Thrift / Vintage Store',
#  'Automotive Shop',
#  'Deli / Bodega',
#  'Buffet',
#  'Mediterranean Restaurant',
#  'Mattress Store']

# %% [markdown]
# #### 3.8 One-hot encode the "Categories" column

# %%
# Mannually select related features for the food warehouse
important_list_of_features = [
    'Neighborhood',
    'Neighborhood Latitude',
    'Neighborhood Longitude',
    'Café',
    'Bakery',
    'Fish & Chips Shop',
    'Restaurant',
    'Pizza Place',
    'Mexican Restaurant',
    'Chinese Restaurant',
    'Sandwich Place',
    'Ice Cream Shop',
    'Breakfast Spot',
    'American Restaurant',
    'Dessert Shop',
    'Italian Restaurant',
    'Indian Restaurant',
    'Fried Chicken Joint',
    'Fast Food Restaurant',
    'Caribbean Restaurant',
    'Moroccan Restaurant',
    'Donut Shop',
    'Sushi Restaurant',
    'French Restaurant',
    'Tapas Restaurant',
    'Seafood Restaurant',
    'Thai Restaurant',
    'Burger Joint',
    'Greek Restaurant',
    'Gourmet Shop',
    'Cupcake Shop',
    'Eastern European Restaurant',
    'Wings Joint',
    'Burrito Place',
    'Middle Eastern Restaurant',
    'BBQ Joint',
    'Comfort Food Restaurant',
    'Asian Restaurant',
    'Buffet',
    'Mediterranean Restaurant']

# %%
etobicoke_onehot = pd.get_dummies(data = etobicoke_venues, 
                                  drop_first  = False, 
                                  prefix = "", 
                                  prefix_sep = "", 
                                  columns = ['Venue Category'])
etobicoke_onehot.drop(columns = ['Unnamed: 0'], inplace = True)
etobicoke_onehot.head()
etobicoke_onehot = etobicoke_onehot[important_list_of_features]
etobicoke_onehot.drop(columns = ['Neighborhood Latitude', 'Neighborhood Longitude'], inplace = True)
etobicoke_onehot = etobicoke_onehot.groupby('Neighborhood').sum()
etobicoke_onehot.head()
# Out:
#                                                     Café  Bakery  \
# Neighborhood
# Alderwood , Long Branch                                0       0
# Eringate , Bloordale Gardens , Old Burnhamthorp...     1       0
# Islington Avenue                                       1       1
# Kingsview Village , St. Phillips , Martin Grove...     0       0
# Mimico NW , The Queensway West , South of Bloor...     1       2
#
#                                                     Fish & Chips Shop  \
# Neighborhood
# Alderwood , Long Branch                                             0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                  1
# Islington Avenue                                                    0
# Kingsview Village , St. Phillips , Martin Grove...                  0
# Mimico NW , The Queensway West , South of Bloor...                  1
#
#                                                     Restaurant  Pizza Place  \
# Neighborhood
# Alderwood , Long Branch                                      0            2
# Eringate , Bloordale Gardens , Old Burnhamthorp...           0            1
# Islington Avenue                                             0            0
# Kingsview Village , St. Phillips , Martin Grove...           0            1
# Mimico NW , The Queensway West , South of Bloor...           5            0
#
#                                                     Mexican Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                              0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                   0
# Islington Avenue                                                     0
# Kingsview Village , St. Phillips , Martin Grove...                   0
# Mimico NW , The Queensway West , South of Bloor...                   1
#
#                                                     Chinese Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                              0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                   0
# Islington Avenue                                                     0
# Kingsview Village , St. Phillips , Martin Grove...                   1
# Mimico NW , The Queensway West , South of Bloor...                   0
#
#                                                     Sandwich Place  \
# Neighborhood
# Alderwood , Long Branch                                          1
# Eringate , Bloordale Gardens , Old Burnhamthorp...               0
# Islington Avenue                                                 0
# Kingsview Village , St. Phillips , Martin Grove...               1
# Mimico NW , The Queensway West , South of Bloor...               1
#
#                                                     Ice Cream Shop  \
# Neighborhood
# Alderwood , Long Branch                                          0
# Eringate , Bloordale Gardens , Old Burnhamthorp...               0
# Islington Avenue                                                 0
# Kingsview Village , St. Phillips , Martin Grove...               0
# Mimico NW , The Queensway West , South of Bloor...               0
#
#                                                     Breakfast Spot  \
# Neighborhood
# Alderwood , Long Branch                                          0
# Eringate , Bloordale Gardens , Old Burnhamthorp...               0
# Islington Avenue                                                 0
# Kingsview Village , St. Phillips , Martin Grove...               0
# Mimico NW , The Queensway West , South of Bloor...               0
#
#                                                     American Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                               0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                    0
# Islington Avenue                                                      0
# Kingsview Village , St. Phillips , Martin Grove...                    1
# Mimico NW , The Queensway West , South of Bloor...                    0
#
#                                                     Dessert Shop  \
# Neighborhood
# Alderwood , Long Branch                                        0
# Eringate , Bloordale Gardens , Old Burnhamthorp...             0
# Islington Avenue                                               0
# Kingsview Village , St. Phillips , Martin Grove...             0
# Mimico NW , The Queensway West , South of Bloor...             0
#
#                                                     Italian Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                              0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                   0
# Islington Avenue                                                     0
# Kingsview Village , St. Phillips , Martin Grove...                   0
# Mimico NW , The Queensway West , South of Bloor...                   1
#
#                                                     Indian Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                             0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                  0
# Islington Avenue                                                    0
# Kingsview Village , St. Phillips , Martin Grove...                  0
# Mimico NW , The Queensway West , South of Bloor...                  0
#
#                                                     Fried Chicken Joint  \
# Neighborhood
# Alderwood , Long Branch                                               0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                    0
# Islington Avenue                                                      0
# Kingsview Village , St. Phillips , Martin Grove...                    0
# Mimico NW , The Queensway West , South of Bloor...                    0
#
#                                                     Fast Food Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                                0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                     0
# Islington Avenue                                                       0
# Kingsview Village , St. Phillips , Martin Grove...                     0
# Mimico NW , The Queensway West , South of Bloor...                     1
#
#                                                     Caribbean Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                                0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                     0
# Islington Avenue                                                       0
# Kingsview Village , St. Phillips , Martin Grove...                     0
# Mimico NW , The Queensway West , South of Bloor...                     0
#
#                                                     Moroccan Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                               1
# Eringate , Bloordale Gardens , Old Burnhamthorp...                    0
# Islington Avenue                                                      0
# Kingsview Village , St. Phillips , Martin Grove...                    0
# Mimico NW , The Queensway West , South of Bloor...                    0
#
#                                                     Donut Shop  \
# Neighborhood
# Alderwood , Long Branch                                      1
# Eringate , Bloordale Gardens , Old Burnhamthorp...           0
# Islington Avenue                                             0
# Kingsview Village , St. Phillips , Martin Grove...           0
# Mimico NW , The Queensway West , South of Bloor...           0
#
#                                                     Sushi Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                            0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                 0
# Islington Avenue                                                   0
# Kingsview Village , St. Phillips , Martin Grove...                 0
# Mimico NW , The Queensway West , South of Bloor...                 2
#
#                                                     French Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                             0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                  0
# Islington Avenue                                                    0
# Kingsview Village , St. Phillips , Martin Grove...                  0
# Mimico NW , The Queensway West , South of Bloor...                  0
#
#                                                     Tapas Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                            0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                 0
# Islington Avenue                                                   0
# Kingsview Village , St. Phillips , Martin Grove...                 0
# Mimico NW , The Queensway West , South of Bloor...                 0
#
#                                                     Seafood Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                              0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                   0
# Islington Avenue                                                     0
# Kingsview Village , St. Phillips , Martin Grove...                   0
# Mimico NW , The Queensway West , South of Bloor...                   0
#
#                                                     Thai Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                           0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                0
# Islington Avenue                                                  0
# Kingsview Village , St. Phillips , Martin Grove...                0
# Mimico NW , The Queensway West , South of Bloor...                1
#
#                                                     Burger Joint  \
# Neighborhood
# Alderwood , Long Branch                                        0
# Eringate , Bloordale Gardens , Old Burnhamthorp...             0
# Islington Avenue                                               0
# Kingsview Village , St. Phillips , Martin Grove...             0
# Mimico NW , The Queensway West , South of Bloor...             2
#
#                                                     Greek Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                            0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                 0
# Islington Avenue                                                   0
# Kingsview Village , St. Phillips , Martin Grove...                 0
# Mimico NW , The Queensway West , South of Bloor...                 0
#
#                                                     Gourmet Shop  \
# Neighborhood
# Alderwood , Long Branch                                        0
# Eringate , Bloordale Gardens , Old Burnhamthorp...             0
# Islington Avenue                                               0
# Kingsview Village , St. Phillips , Martin Grove...             0
# Mimico NW , The Queensway West , South of Bloor...             0
#
#                                                     Cupcake Shop  \
# Neighborhood
# Alderwood , Long Branch                                        0
# Eringate , Bloordale Gardens , Old Burnhamthorp...             0
# Islington Avenue                                               0
# Kingsview Village , St. Phillips , Martin Grove...             0
# Mimico NW , The Queensway West , South of Bloor...             0
#
#                                                     Eastern European Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                                       0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                            0
# Islington Avenue                                                              0
# Kingsview Village , St. Phillips , Martin Grove...                            0
# Mimico NW , The Queensway West , South of Bloor...                            0
#
#                                                     Wings Joint  \
# Neighborhood
# Alderwood , Long Branch                                       0
# Eringate , Bloordale Gardens , Old Burnhamthorp...            0
# Islington Avenue                                              0
# Kingsview Village , St. Phillips , Martin Grove...            0
# Mimico NW , The Queensway West , South of Bloor...            1
#
#                                                     Burrito Place  \
# Neighborhood
# Alderwood , Long Branch                                         0
# Eringate , Bloordale Gardens , Old Burnhamthorp...              0
# Islington Avenue                                                0
# Kingsview Village , St. Phillips , Martin Grove...              0
# Mimico NW , The Queensway West , South of Bloor...              3
#
#                                                     Middle Eastern Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                                     0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                          0
# Islington Avenue                                                            0
# Kingsview Village , St. Phillips , Martin Grove...                          0
# Mimico NW , The Queensway West , South of Bloor...                          1
#
#                                                     BBQ Joint  \
# Neighborhood
# Alderwood , Long Branch                                     0
# Eringate , Bloordale Gardens , Old Burnhamthorp...          0
# Islington Avenue                                            0
# Kingsview Village , St. Phillips , Martin Grove...          0
# Mimico NW , The Queensway West , South of Bloor...          1
#
#                                                     Comfort Food Restaurant  \
# Neighborhood
# Alderwood , Long Branch                                                   0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                        0
# Islington Avenue                                                          0
# Kingsview Village , St. Phillips , Martin Grove...                        0
# Mimico NW , The Queensway West , South of Bloor...                        1
#
#                                                     Asian Restaurant  Buffet  \
# Neighborhood
# Alderwood , Long Branch                                            0       0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                 0       0
# Islington Avenue                                                   0       0
# Kingsview Village , St. Phillips , Martin Grove...                 0       0
# Mimico NW , The Queensway West , South of Bloor...                 1       1
#
#                                                     Mediterranean Restaurant
# Neighborhood
# Alderwood , Long Branch                                                    0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                         0
# Islington Avenue                                                           0
# Kingsview Village , St. Phillips , Martin Grove...                         0
# Mimico NW , The Queensway West , South of Bloor...                         1

# %% [markdown]
# #### 3.9 Integrating different restaurants

# %%
feat_name_list = list(etobicoke_onehot.columns)
restaurant_list = []

for counter, value in enumerate(feat_name_list):
    if value.find('Restaurant') != (-1):
        restaurant_list.append(value)
        
etobicoke_onehot['Total Restaurants'] = etobicoke_onehot[restaurant_list].sum(axis = 1)
etobicoke_onehot = etobicoke_onehot.drop(columns = restaurant_list)


feat_name_list = list(etobicoke_onehot.columns)
joint_list = []


for counter, value in enumerate(feat_name_list):
    if value.find('Joint') != (-1):
        joint_list.append(value)
        
etobicoke_onehot['Total Joints'] = etobicoke_onehot[joint_list].sum(axis = 1)
etobicoke_onehot = etobicoke_onehot.drop(columns = joint_list)
etobicoke_onehot
# Out:
#                                                     Café  Bakery  \
# Neighborhood
# Alderwood , Long Branch                                0       0
# Eringate , Bloordale Gardens , Old Burnhamthorp...     1       0
# Islington Avenue                                       1       1
# Kingsview Village , St. Phillips , Martin Grove...     0       0
# Mimico NW , The Queensway West , South of Bloor...     1       2
# New Toronto , Mimico South , Humber Bay Shores         1       1
# Old Mill South , King's Mill Park , Sunnylea , ...     0       0
# South Steeles , Silverstone , Humbergate , Jame...     0       0
# The Kingsway , Montgomery Road , Old Mill North        1       1
# West Deane Park , Princess Gardens , Martin Gro...     0       0
# Westmount                                              0       0
#
#                                                     Fish & Chips Shop  \
# Neighborhood
# Alderwood , Long Branch                                             0
# Eringate , Bloordale Gardens , Old Burnhamthorp...                  1
# Islington Avenue                                                    0
# Kingsview Village , St. Phillips , Martin Grove...                  0
# Mimico NW , The Queensway West , South of Bloor...                  1
# New Toronto , Mimico South , Humber Bay Shores                      0
# Old Mill South , King's Mill Park , Sunnylea , ...                  0
# South Steeles , Silverstone , Humbergate , Jame...                  0
# The Kingsway , Montgomery Road , Old Mill North                     0
# West Deane Park , Princess Gardens , Martin Gro...                  1
# Westmount                                                           0
#
#                                                     Pizza Place  \
# Neighborhood
# Alderwood , Long Branch                                       2
# Eringate , Bloordale Gardens , Old Burnhamthorp...            1
# Islington Avenue                                              0
# Kingsview Village , St. Phillips , Martin Grove...            1
# Mimico NW , The Queensway West , South of Bloor...            0
# New Toronto , Mimico South , Humber Bay Shores                1
# Old Mill South , King's Mill Park , Sunnylea , ...            0
# South Steeles , Silverstone , Humbergate , Jame...            3
# The Kingsway , Montgomery Road , Old Mill North               2
# West Deane Park , Princess Gardens , Martin Gro...            2
# Westmount                                                     2
#
#                                                     Sandwich Place  \
# Neighborhood
# Alderwood , Long Branch                                          1
# Eringate , Bloordale Gardens , Old Burnhamthorp...               0
# Islington Avenue                                                 0
# Kingsview Village , St. Phillips , Martin Grove...               1
# Mimico NW , The Queensway West , South of Bloor...               1
# New Toronto , Mimico South , Humber Bay Shores                   0
# Old Mill South , King's Mill Park , Sunnylea , ...               0
# South Steeles , Silverstone , Humbergate , Jame...               1
# The Kingsway , Montgomery Road , Old Mill North                  0
# West Deane Park , Princess Gardens , Martin Gro...               0
# Westmount                                                        1
#
#                                                     Ice Cream Shop  \
# Neighborhood
# Alderwood , Long Branch                                          0
# Eringate , Bloordale Gardens , Old Burnhamthorp...               0
# Islington Avenue                                                 0
# Kingsview Village , St. Phillips , Martin Grove...               0
# Mimico NW , The Queensway West , South of Bloor...               0
# New Toronto , Mimico South , Humber Bay Shores                   0
# Old Mill South , King's Mill Park , Sunnylea , ...               1
# South Steeles , Silverstone , Humbergate , Jame...               0
# The Kingsway , Montgomery Road , Old Mill North                  0
# West Deane Park , Princess Gardens , Martin Gro...               0
# Westmount                                                        1
#
#                                                     Breakfast Spot  \
# Neighborhood
# Alderwood , Long Branch                                          0
# Eringate , Bloordale Gardens , Old Burnhamthorp...               0
# Islington Avenue                                                 0
# Kingsview Village , St. Phillips , Martin Grove...               0
# Mimico NW , The Queensway West , South of Bloor...               0
# New Toronto , Mimico South , Humber Bay Shores                   1
# Old Mill South , King's Mill Park , Sunnylea , ...               0
# South Steeles , Silverstone , Humbergate , Jame...               0
# The Kingsway , Montgomery Road , Old Mill North                  2
# West Deane Park , Princess Gardens , Martin Gro...               0
# Westmount                                                        1
#
#                                                     Dessert Shop  Donut Shop  \
# Neighborhood
# Alderwood , Long Branch                                        0           1
# Eringate , Bloordale Gardens , Old Burnhamthorp...             0           0
# Islington Avenue                                               0           0
# Kingsview Village , St. Phillips , Martin Grove...             0           0
# Mimico NW , The Queensway West , South of Bloor...             0           0
# New Toronto , Mimico South , Humber Bay Shores                 1           0
# Old Mill South , King's Mill Park , Sunnylea , ...             0           0
# South Steeles , Silverstone , Humbergate , Jame...             0           0
# The Kingsway , Montgomery Road , Old Mill North                2           0
# West Deane Park , Princess Gardens , Martin Gro...             0           0
# Westmount                                                      0           0
#
#                                                     Gourmet Shop  \
# Neighborhood
# Alderwood , Long Branch                                        0
# Eringate , Bloordale Gardens , Old Burnhamthorp...             0
# Islington Avenue                                               0
# Kingsview Village , St. Phillips , Martin Grove...             0
# Mimico NW , The Queensway West , South of Bloor...             0
# New Toronto , Mimico South , Humber Bay Shores                 0
# Old Mill South , King's Mill Park , Sunnylea , ...             0
# South Steeles , Silverstone , Humbergate , Jame...             0
# The Kingsway , Montgomery Road , Old Mill North                1
# West Deane Park , Princess Gardens , Martin Gro...             0
# Westmount                                                      0
#
#                                                     Cupcake Shop  \
# Neighborhood
# Alderwood , Long Branch                                        0
# Eringate , Bloordale Gardens , Old Burnhamthorp...             0
# Islington Avenue                                               0
# Kingsview Village , St. Phillips , Martin Grove...             0
# Mimico NW , The Queensway West , South of Bloor...             0
# New Toronto , Mimico South , Humber Bay Shores                 0
# Old Mill South , King's Mill Park , Sunnylea , ...             0
# South Steeles , Silverstone , Humbergate , Jame...             0
# The Kingsway , Montgomery Road , Old Mill North                1
# West Deane Park , Princess Gardens , Martin Gro...             0
# Westmount                                                      0
#
#                                                     Burrito Place  Buffet  \
# Neighborhood
# Alderwood , Long Branch                                         0       0
# Eringate , Bloordale Gardens , Old Burnhamthorp...              0       0
# Islington Avenue                                                0       0
# Kingsview Village , St. Phillips , Martin Grove...              0       0
# Mimico NW , The Queensway West , South of Bloor...              3       1
# New Toronto , Mimico South , Humber Bay Shores                  0       0
# Old Mill South , King's Mill Park , Sunnylea , ...              0       0
# South Steeles , Silverstone , Humbergate , Jame...              0       0
# The Kingsway , Montgomery Road , Old Mill North                 0       0
# West Deane Park , Princess Gardens , Martin Gro...              0       0
# Westmount                                                       0       0
#
#                                                     Total Restaurants  \
# Neighborhood
# Alderwood , Long Branch                                             1
# Eringate , Bloordale Gardens , Old Burnhamthorp...                  0
# Islington Avenue                                                    0
# Kingsview Village , St. Phillips , Martin Grove...                  2
# Mimico NW , The Queensway West , South of Bloor...                 15
# New Toronto , Mimico South , Humber Bay Shores                      6
# Old Mill South , King's Mill Park , Sunnylea , ...                  3
# South Steeles , Silverstone , Humbergate , Jame...                  2
# The Kingsway , Montgomery Road , Old Mill North                    12
# West Deane Park , Princess Gardens , Martin Gro...                  2
# Westmount                                                           1
#
#                                                     Total Joints
# Neighborhood
# Alderwood , Long Branch                                        0
# Eringate , Bloordale Gardens , Old Burnhamthorp...             0
# Islington Avenue                                               0
# Kingsview Village , St. Phillips , Martin Grove...             0
# Mimico NW , The Queensway West , South of Bloor...             4
# New Toronto , Mimico South , Humber Bay Shores                 1
# Old Mill South , King's Mill Park , Sunnylea , ...             0
# South Steeles , Silverstone , Humbergate , Jame...             1
# The Kingsway , Montgomery Road , Old Mill North                2
# West Deane Park , Princess Gardens , Martin Gro...             0
# Westmount                                                      0

# %% [markdown]
# #### 3.10 Run K-means algorithm to cluster the neighborhoods into 3 groups

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 3, random_state = 2).fit(etobicoke_onehot)

# %%
# show center of each cluster
means_df = pd.DataFrame(kmeans.cluster_centers_)
means_df.columns = etobicoke_onehot.columns
means_df.index = ['G1','G2','G3']
means_df['Total Sum'] = means_df.sum(axis = 1)
means_df.sort_values(axis = 0, by = ['Total Sum'], ascending=False)
# Out:
#     Café  Bakery  Fish & Chips Shop  Pizza Place  Sandwich Place  \
# G3  1.00   1.500               0.50        1.000             0.5
# G1  1.00   1.000               0.00        1.000             0.0
# G2  0.25   0.125               0.25        1.375             0.5
#
#     Ice Cream Shop  Breakfast Spot  Dessert Shop  Donut Shop  Gourmet Shop  \
# G3            0.00           1.000           1.0       0.000  5.000000e-01
# G1            0.00           1.000           1.0       0.000  0.000000e+00
# G2            0.25           0.125           0.0       0.125 -1.387779e-17
#
#     Cupcake Shop  Burrito Place        Buffet  Total Restaurants  \
# G3  5.000000e-01            1.5  5.000000e-01             13.500
# G1  0.000000e+00            0.0  0.000000e+00              6.000
# G2 -1.387779e-17            0.0 -1.387779e-17              1.375
#
#     Total Joints  Total Sum
# G3         3.000       26.0
# G1         1.000       12.0
# G2         0.125        4.5

# %% [markdown]
# > We can see the best is G3, second best is G1, third best is G2.

# %%
neigh_summary = pd.DataFrame([etobicoke_onehot.index, 1 + kmeans.labels_]).T
neigh_summary.columns = ['Neighborhood', 'Group']
neigh_summary
# Out:
#                                          Neighborhood Group
# 0                             Alderwood , Long Branch     2
# 1   Eringate , Bloordale Gardens , Old Burnhamthor...     2
# 2                                    Islington Avenue     2
# 3   Kingsview Village , St. Phillips , Martin Grov...     2
# 4   Mimico NW , The Queensway West , South of Bloo...     3
# 5      New Toronto , Mimico South , Humber Bay Shores     1
# 6   Old Mill South , King's Mill Park , Sunnylea ,...     2
# 7   South Steeles , Silverstone , Humbergate , Jam...     2
# 8     The Kingsway , Montgomery Road , Old Mill North     3
# 9   West Deane Park , Princess Gardens , Martin Gr...     2
# 10                                          Westmount     2

# %% [markdown]
# #### 3.11 Top 3 neighborhoods are...

# %%
neigh_summary[neigh_summary['Group'] == 3]
# Out:
#                                         Neighborhood Group
# 4  Mimico NW , The Queensway West , South of Bloo...     3
# 8    The Kingsway , Montgomery Road , Old Mill North     3

# %%
neigh_summary[neigh_summary['Group'] == 1]
# Out:
#                                      Neighborhood Group
# 5  New Toronto , Mimico South , Humber Bay Shores     1

# %% [markdown]
# ## Thanks for reading!
